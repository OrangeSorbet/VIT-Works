# %% [markdown]
# ## Section 1: Unit 1
# ### Task 1: Collect Dataset & Visualize

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Cardiovascular_Disease_Dataset.csv')
df.head()

# Identify numerical and categorical columns
numerical_cols = df.select_dtypes(include='number').columns
categorical_cols = df.select_dtypes(include='object').columns

print('Numerical Columns:', numerical_cols)
print('Categorical Columns:', categorical_cols)

# Visualize numerical distributions
for col in numerical_cols:
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.show()

# Visualize categorical distributions
for col in categorical_cols:
    sns.countplot(x=col, data=df, palette='Set2')
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# Numerical Columns: Index(['patientid', 'age', 'gender', 'chestpain', 'restingBP',
#        'serumcholestrol', 'fastingbloodsugar', 'restingrelectro',
#        'maxheartrate', 'exerciseangia', 'oldpeak', 'slope', 'noofmajorvessels',
#        'target'],
#       dtype='object')
# Categorical Columns: Index([], dtype='object')

# %% [markdown]
# ### Task 2: Compare Mean & Median for Skewed Datasets

# %%
for col in numerical_cols:
    mean_val = df[col].mean()
    median_val = df[col].median()
    print(f'{col}: Mean={mean_val}, Median={median_val}')

# Comment: For skewed distributions, median is more robust against outliers.
# Out:
# patientid: Mean=5048704.412, Median=4952508.5
# age: Mean=49.242, Median=49.0
# gender: Mean=0.765, Median=1.0
# chestpain: Mean=0.98, Median=1.0
# restingBP: Mean=151.747, Median=147.0
# serumcholestrol: Mean=311.447, Median=318.0
# fastingbloodsugar: Mean=0.296, Median=0.0
# restingrelectro: Mean=0.748, Median=1.0
# maxheartrate: Mean=145.477, Median=146.0
# exerciseangia: Mean=0.498, Median=0.0
# oldpeak: Mean=2.7077, Median=2.4
# slope: Mean=1.54, Median=2.0
# noofmajorvessels: Mean=1.222, Median=1.0
# target: Mean=0.58, Median=1.0

# %% [markdown]
# ### Task 3: Mini-Report on Sampling Strategy
# - **Simple Random Sampling:** Equal chance for each student.
# - **Stratified Sampling:** Proportional representation by department/year/gender.
# - **Cluster Sampling:** Surveying full classes/batches.
# - **Recommended:** Stratified sampling for campus surveys ensures fair representation.

# %% [markdown]
# ## Unit 2: Probability

# %% [markdown]
# ### Task 1: Binomial Probability

# %%
from scipy.stats import binom

# Example: 10 products, 10% defect, probability of 2 defective
n, p, k = 10, 0.1, 2
prob = binom.pmf(k, n, p)
print('Binomial Probability:', prob)
# Out:
# Binomial Probability: 0.19371024450000007

# %% [markdown]
# ### Task 2: Z-score Calculation

# %%
x, mu, sigma = 85, 80, 5
z = (x - mu) / sigma
print('Z-score:', z)
# Out:
# Z-score: 1.0

# %% [markdown]
# ### Task 3: Normal Approximation to Binomial

# %%
from scipy.stats import norm

mu_norm, sigma_norm = n*p, (n*p*(1-p))**0.5
prob_norm = norm.pdf(k, mu_norm, sigma_norm)
print('Normal Approximation Probability:', prob_norm)
# Out:
# Normal Approximation Probability: 0.24127598591382216

# %% [markdown]
# ## Section 2: Unit 3

# %% [markdown]
# ### Task 1: 95% Confidence Interval for Proportion

# %%
import statsmodels.api as sm
success, n_total = 45, 100
ci_low, ci_high = sm.stats.proportion_confint(success, n_total, alpha=0.05, method='normal')
print(f'95% CI for proportion: ({ci_low:.3f}, {ci_high:.3f})')
# Out:
# 95% CI for proportion: (0.352, 0.548)

# %% [markdown]
# ### Task 2: Hypothesis Test for Population Mean

# %%
from scipy import stats
sample = [10, 12, 9, 11, 13]
t_stat, p_val = stats.ttest_1samp(sample, popmean=10)
print('t-statistic:', t_stat, 'p-value:', p_val)
# Out:
# t-statistic: 1.414213562373095 p-value: 0.23019964108049873

# %% [markdown]
# ### Task 3: One-way ANOVA

# %%
group1 = [10, 12, 11]
group2 = [14, 15, 16]
group3 = [13, 14, 15]

f_stat, p_val = stats.f_oneway(group1, group2, group3)
print('ANOVA F-statistic:', f_stat, 'p-value:', p_val)
# Out:
# ANOVA F-statistic: 13.000000000000025 p-value: 0.0065917968749999705

# %% [markdown]
# ## Unit 4: t-tests

# %% [markdown]
# ### Task 1: Paired t-test (Before & After)

# %%
before = [50, 55, 60]
after = [52, 57, 63]
t_stat, p_val = stats.ttest_rel(before, after)
print('Paired t-test: t-statistic:', t_stat, 'p-value:', p_val)
# Out:
# Paired t-test: t-statistic: -7.0 p-value: 0.019803941180393136

# %% [markdown]
# ### Task 2: Independent Two-sample t-test

# %%
machine1 = [10, 12, 11]
machine2 = [14, 15, 13]
t_stat, p_val = stats.ttest_ind(machine1, machine2)
print('Independent t-test: t-statistic:', t_stat, 'p-value:', p_val)
# Out:
# Independent t-test: t-statistic: -3.6742346141747673 p-value: 0.021311641128756723

# %% [markdown]
# ## Additional Python Tutorial Tasks

# %%
# Random Sampling
sample_df = df.sample(n=10, random_state=42)
sample_df.mean()
# Out:
# patientid            5960156.60
# age                       52.70
# gender                     0.80
# chestpain                  0.50
# restingBP                150.40
# serumcholestrol          214.50
# fastingbloodsugar          0.00
# restingrelectro            0.40
# maxheartrate             160.50
# exerciseangia              0.50
# oldpeak                    1.75
# slope                      1.40
# noofmajorvessels           1.10
# target                     0.50
# dtype: float64

# %%
# Manual Binomial Probability Function
from math import comb
def binomial_prob(n, k, p):
    return comb(n, k)*(p**k)*((1-p)**(n-k))

print('Manual Binomial Probability:', binomial_prob(10, 2, 0.1))
# Out:
# Manual Binomial Probability: 0.19371024450000007

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# define parameters
mu = 50        # mean
sigma = 10     # standard deviation

x_vals = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
y_vals = norm.pdf(x_vals, mu, sigma)

plt.plot(x_vals, y_vals)
plt.title('Normal Distribution Curve')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# choose ONE numerical column
col = numerical_cols[0]

sample_means = [
    df[col].sample(10, replace=True).mean()
    for _ in range(1000)
]

sns.histplot(sample_means, kde=True)
plt.title('Sampling Distribution of Sample Means (CLT)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 numerical_cols = df.select_dtypes(include=np.number).columns.tolist()
#       6 # choose ONE numerical column
#       7 col = numerical_cols[0]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### End-to-End Case Study
# 1. Load dataset → 2. EDA → 3. Select test → 4. Perform inferential analysis → 5. Report conclusion
#
# You can use the above sections to perform this final step.
